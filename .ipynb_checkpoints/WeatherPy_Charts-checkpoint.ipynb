# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from citipy import citipy
from scipy.stats import linregress

# %%
cities_data = pd.read_csv("Cities_database/Cities_database.csv")

# %%
cities_data.head()
# Out:
#    City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0     Esperance      AU -33.8667  121.9000     72.95        72
# 1        1       Ushuaia      AR -54.8000  -68.3000     47.86        87
# 2        2   Provideniya      RU  64.3833 -173.3000     -3.89        59
# 3        3        Kodiak      US  57.7900 -152.4072     33.31        69
# 4        4  Norman Wells      CA  65.2820 -126.8329    -11.16        70
#
#    Cloudiness  Wind Speed Current Description
# 0           0       18.77           clear sky
# 1         100       23.02          light rain
# 2          40       11.18    scattered clouds
# 3          40        3.44    scattered clouds
# 4         100        4.61          light snow

# %% [markdown]
# ### Requirement#1

# %%
plt.scatter(cities_data['Lat'],cities_data['Max Temp'])
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.show()

# %%
plt.scatter(cities_data['Lat'],cities_data['Humidity'])
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()

# %%
plt.scatter(cities_data['Lat'],cities_data['Cloudiness'])
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()

# %%
plt.scatter(cities_data['Lat'],cities_data['Wind Speed'])
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()

# %% [markdown]
# ### Requirement#2

# %%
northern_cities = cities_data[cities_data['Lat']>=0]

# %%
southern_cities = cities_data[cities_data['Lat']<0]

# %%
#Northern Hemisphere: Temperature vs. Latitude
x_values = northern_cities['Lat']
y_values = northern_cities['Max Temp']
plt.scatter(x_value,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.show()

# %%
southern_cities = southern_cities.dropna(how='any')

# %%
#Southern Hemisphere: Temperature vs. Latitude

# %%
#Southern Hemisphere: Temperature vs. Latitude
x_values = southern_cities['Lat']
y_values = southern_cities['Max Temp']
plt.scatter(southern_cities['Lat'],southern_cities['Max Temp'])
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities['Lat'], southern_cities['Max Temp'])
regress_values = southern_cities['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(southern_cities['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-50,90),fontsize=15,color="red")
plt.show()

# %%
#Northern Hemisphere: Humidity vs. Latitude
x_values = northern_cities['Lat']
y_values = northern_cities['Humidity']
plt.scatter(x_value,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.show()

# %%
#Southern Hemisphere: Humidity vs. Latitude
x_values = southern_cities['Lat']
y_values = southern_cities['Humidity']
plt.scatter(southern_cities['Lat'],southern_cities['Humidity'])
plt.xlabel('Latitude')
plt.ylabel('Humidity')
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities['Lat'], southern_cities['Humidity'])
regress_values = southern_cities['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(southern_cities['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-30,20),fontsize=15,color="red")
plt.show()

# %%
#Northern Hemisphere: Cloudiness vs. Latitude
x_values = northern_cities['Lat']
y_values = northern_cities['Cloudiness']
plt.scatter(x_value,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.show()

# %%
#Southern Hemisphere: Cloudiness vs. Latitude
x_values = southern_cities['Lat']
y_values = southern_cities['Cloudiness']
plt.scatter(southern_cities['Lat'],southern_cities['Cloudiness'])
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities['Lat'], southern_cities['Cloudiness'])
regress_values = southern_cities['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(southern_cities['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-50,40),fontsize=15,color="red")
plt.show()

# %%
#Northern Hemisphere: Wind Speed vs. Latitude
x_values = northern_cities['Lat']
y_values = northern_cities['Wind Speed']
plt.scatter(x_value,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,40),fontsize=15,color="red")
plt.show()

# %%
#Southern Hemisphere: Wind Speed vs. Latitude
x_values = southern_cities['Lat']
y_values = southern_cities['Wind Speed']
plt.scatter(southern_cities['Lat'],southern_cities['Wind Speed'])
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
(slope, intercept, rvalue, pvalue, stderr) = linregress(southern_cities['Lat'], southern_cities['Wind Speed'])
regress_values = southern_cities['Lat'] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(southern_cities['Lat'],regress_values,"r-")
plt.annotate(line_eq,(-50,25),fontsize=15,color="red")
plt.show()
