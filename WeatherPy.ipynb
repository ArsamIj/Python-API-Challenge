# %%
import pandas as pd
import numpy as np

import requests


from citipy import citipy

# %%
#Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

coordinates = list(lat_lngs)

# %%
#4. Get the nearest city using the citipy module.
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 759

# %%
#5. Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b73c94334bbd51888431cc30d86df7d4"

city_database = []

for city in cities:
    city_url = url + "&q=" + city.replace(" ","+")
    try:
        # 6. Retrieve the information from the API call.
        city_weather = requests.get(city_url).json()

        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"] #{dictionary[list{dictionary}]} ∴ 3 indices
        
        city_database.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
                            #Date is not an option in the data found in the API
    except:
        print("City not found. Skipping...")
        pass
    
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# ...

# %%
#7. Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_database)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Esperance      AU -33.8667  121.9000     72.95        72           0
# 1       Ushuaia      AR -54.8000  -68.3000     47.86        87         100
# 2   Provideniya      RU  64.3833 -173.3000     -3.89        59          40
# 3        Kodiak      US  57.7900 -152.4072     33.31        69          40
# 4  Norman Wells      CA  65.2820 -126.8329    -11.16        70         100
# 5     Jamestown      US  42.0970  -79.2353     31.01        93         100
# 6     Carnarvon      AU -24.8667  113.6333     83.07        50           0
# 7         Taman      RU  45.2117   36.7161     31.87        75         100
# 8   Yellowknife      CA  62.4560 -114.3525     -3.48        77          75
# 9      Ilhabela      BR -23.7781  -45.3581     75.52        88          32
#
#    Wind Speed Current Description
# 0       18.77           clear sky
# 1       23.02          light rain
# 2       11.18    scattered clouds
# ...

# %%
city_data_df.count() #checking if any empty values in there DataFrame
# Out:
# City                   690
# Country                690
# Lat                    690
# Lng                    690
# Max Temp               690
# Humidity               690
# Cloudiness             690
# Wind Speed             690
# Current Description    690
# dtype: int64

# %%
#8. Export the DataFrame as a CSV file
output_data_file = "Cities_database/Cities_database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
